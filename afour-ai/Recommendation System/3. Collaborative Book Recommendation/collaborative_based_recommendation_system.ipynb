# %% [markdown]
# ###Importing Packages

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter

import numpy as np
import pandas as pd

# %% [markdown]
# ###Data Preprocessing

# %%
from pathlib import Path
import os
import sys

sys.path.append(str(Path(os.getcwd()).parents[1]))
from Helper_Functions import common_utils
directory_to_extract_to = os.getcwd()

common_utils.load_data_from_one_drive(directory_to_extract_to, 'recommendation_paths', 'coll_book_recommendation')
# Out:
# Extracting : 100%|██████████| 3/3 [00:00<00:00,  3.07it/s]

# %%
books = pd.read_csv('Books.csv')
users = pd.read_csv('Users.csv')
ratings = pd.read_csv('Ratings.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (264060, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###Popularity-based Recommendation system

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 234742                                      Ã?Â?lpiraten.            2
# 234743                     Ã?Â?rger mit Produkt X. Roman.            4
# 234744                                Ã?Â?sterlich leben.            1
# 234745                              Ã?Â?stlich der Berge.            3
# 234746                                  Ã?Â?thique en toc            2
#
# [234747 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# 4        Clifford Visita El Hospital (Clifford El Gran...    0.000000
# ...                                                   ...         ...
# 234742                                      Ã?Â?lpiraten.    0.000000
# 234743                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 234744                                Ã?Â?sterlich leben.    7.000000
# 234745                              Ã?Â?stlich der Berge.    2.666667
# 234746                                  Ã?Â?thique en toc    4.000000
#
# [234747 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 234742                                      Ã?Â?lpiraten.            2
# 234743                     Ã?Â?rger mit Produkt X. Roman.            4
# 234744                                Ã?Â?sterlich leben.            1
# 234745                              Ã?Â?stlich der Berge.            3
# 234746                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
# ...            ...
# 234742    0.000000
# 234743    5.250000
# 234744    7.000000
# 234745    2.666667
# 234746    4.000000
#
# [234747 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df.sort_values(ascending=True, by='num_ratings')
# Out:
#                                             Book-Title  \
# 98                                       Into the Wild
# 70                            Prodigal Summer: A Novel
# 160                               Silence of the Lambs
# 183                                  Lord of the Flies
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 163                                        About a Boy
# 71                                          Neverwhere
# 131  A Child Called \It\": One Child's Courage to S...
# 172  The Alchemist: A Fable About Following Your Dream
# 87                The Hitchhiker's Guide to the Galaxy
# 174  Hard Eight : A Stephanie Plum Novel (A Stephan...
# 122                     Seabiscuit: An American Legend
# 170                  Seven Up (A Stephanie Plum Novel)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 133                                     ANGELA'S ASHES
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 61                                                1984
# 115                                          Outlander
# 82   Stupid White Men ...and Other Sorry Excuses fo...
# 191   The Vampire Lestat (Vampire Chronicles, Book II)
# 143                                      American Gods
# 154                                   The Color Purple
# 144  Left Behind: A Novel of the Earth's Last Days ...
# 138                                 Skipping Christmas
# 137  Fast Food Nation: The Dark Side of the All-Ame...
# 96    Nickel and Dimed: On (Not) Getting By in America
# 146    The Golden Compass (His Dark Materials, Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 192       White Oleander : A Novel (Oprah's Book Club)
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 128                                     The Bean Trees
# 101                                     Fahrenheit 451
# 189                            A Prayer for Owen Meany
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 52                  The Five People You Meet in Heaven
# 54                              The Catcher in the Rye
# 179                       Suzanne's Diary for Nicholas
# 135                                        Good in Bed
# 83   Tuesdays with Morrie: An Old Man, a Young Man,...
# 38                               To Kill a Mockingbird
# 114                          Girl with a Pearl Earring
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 121  Where the Heart Is (Oprah's Book Club (Paperba...
# 124                                         Life of Pi
# 86                 The Red Tent (Bestselling Backlist)
# 76                             The Secret Life of Bees
# 46                                   The Da Vinci Code
# 69                           The Lovely Bones: A Novel
#
#                 Book-Author  \
# 98             Jon Krakauer
# 70       Barbara Kingsolver
# 160           Thomas Harris
# 183  William Gerald Golding
# 28           J.R.R. TOLKIEN
# 163             Nick Hornby
# 71              Neil Gaiman
# 131             Dave Pelzer
# 172            Paulo Coelho
# 87            Douglas Adams
# 174         Janet Evanovich
# 122       LAURA HILLENBRAND
# 170         Janet Evanovich
# 5             J. K. Rowling
# 133           Frank McCourt
# 16           J.R.R. TOLKIEN
# 61            George Orwell
# 115          DIANA GABALDON
# 82            Michael Moore
# 191               ANNE RICE
# 143             Neil Gaiman
# 154            Alice Walker
# 144              Tim Lahaye
# 138            JOHN GRISHAM
# 137          Eric Schlosser
# 96       Barbara Ehrenreich
# 146          PHILIP PULLMAN
# 9             J. K. Rowling
# 192             Janet Fitch
# 17           J.R.R. TOLKIEN
# 3             J. K. Rowling
# 128      Barbara Kingsolver
# 101            Ray Bradbury
# 189             John Irving
# 0             J. K. Rowling
# 52              Mitch Albom
# 54            J.D. Salinger
# 179         James Patterson
# 135         Jennifer Weiner
# 83              MITCH ALBOM
# 38               Harper Lee
# 114         Tracy Chevalier
# 13            J. K. Rowling
# 26            J. K. Rowling
# 121            Billie Letts
# 124             Yann Martel
# 86            Anita Diamant
# 76            Sue Monk Kidd
# 46                Dan Brown
# 69             Alice Sebold
#
#                                            Image-URL-M  num_ratings  \
# 98   http://images.amazon.com/images/P/0385486804.0...          252
# 70   http://images.amazon.com/images/P/0060959037.0...          253
# 160  http://images.amazon.com/images/P/0312924585.0...          256
# 183  http://images.amazon.com/images/P/0399501487.0...          259
# 28   http://images.amazon.com/images/P/0345339711.0...          259
# 163  http://images.amazon.com/images/P/1573227331.0...          262
# 71   http://images.amazon.com/images/P/0380789019.0...          265
# 131  http://images.amazon.com/images/P/1558743669.0...          265
# 172  http://images.amazon.com/images/P/0062502174.0...          266
# 87   http://images.amazon.com/images/P/0671461494.0...          268
# 174  http://images.amazon.com/images/P/0312983867.0...          269
# 122  http://images.amazon.com/images/P/0449005615.0...          275
# 170  http://images.amazon.com/images/P/0312265840.0...          278
# 5    http://images.amazon.com/images/P/0590353403.0...          278
# 133  http://images.amazon.com/images/P/0684874350.0...          279
# 16   http://images.amazon.com/images/P/0345339681.0...          281
# 61   http://images.amazon.com/images/P/0451524934.0...          283
# 115  http://images.amazon.com/images/P/0440222915.0...          283
# 82   http://images.amazon.com/images/P/0060392452.0...          283
# 191  http://images.amazon.com/images/P/0345313860.0...          301
# 143  http://images.amazon.com/images/P/0380789035.0...          302
# 154  http://images.amazon.com/images/P/0671617028.0...          314
# 144  http://images.amazon.com/images/P/0842329129.0...          318
# 138  http://images.amazon.com/images/P/0385505833.0...          321
# 137  http://images.amazon.com/images/P/0060938455.0...          321
# 96   http://images.amazon.com/images/P/0805063897.0...          335
# 146  http://images.amazon.com/images/P/037582345X.0...          336
# 9    http://images.amazon.com/images/P/043935806X.0...          347
# 192  http://images.amazon.com/images/P/0316284955.0...          356
# 17   http://images.amazon.com/images/P/0345339703.0...          368
# 3    http://images.amazon.com/images/P/0439139597.0...          387
# 128  http://images.amazon.com/images/P/0060915544.0...          389
# 101  http://images.amazon.com/images/P/3257208626.0...          409
# 189  http://images.amazon.com/images/P/0345361792.0...          413
# 0    http://images.amazon.com/images/P/0439136350.0...          428
# 52   http://images.amazon.com/images/P/0786868716.0...          430
# 54   http://images.amazon.com/images/P/0316769487.0...          449
# 179  http://images.amazon.com/images/P/0316969443.0...          457
# 135  http://images.amazon.com/images/P/0743418174.0...          490
# 83   http://images.amazon.com/images/P/0385484518.0...          493
# 38   http://images.amazon.com/images/P/0446310786.0...          510
# 114  http://images.amazon.com/images/P/0452282152.0...          526
# 13   http://images.amazon.com/images/P/0439064872.0...          556
# 26   http://images.amazon.com/images/P/059035342X.0...          575
# 121  http://images.amazon.com/images/P/0446672211.0...          585
# 124  http://images.amazon.com/images/P/0151008116.0...          664
# 86   http://images.amazon.com/images/P/0312195516.0...          723
# 76   http://images.amazon.com/images/P/0142001740.0...          774
# 46   http://images.amazon.com/images/P/0385504209.0...          898
# 69   http://images.amazon.com/images/P/0316666343.0...         1295
#
#      avg_rating
# 98     4.273810
# 70     4.450593
# 160    3.960938
# 183    3.818533
# 28     4.861004
# 163    3.900763
# 71     4.449057
# 131    4.086792
# 172    3.875940
# 87     4.328358
# 174    3.825279
# 122    4.098182
# 170    3.888489
# 5      5.737410
# 133    4.075269
# 16     5.007117
# 61     4.469965
# 115    4.173145
# 82     4.356890
# 191    3.777409
# 143    4.006623
# 154    3.964968
# 144    4.003145
# 138    4.018692
# 137    4.037383
# 96     4.289552
# 146    4.000000
# 9      5.501441
# 192    3.772472
# 17     4.948370
# 3      5.824289
# 128    4.087404
# 101    4.264059
# 189    3.796610
# 0      5.852804
# 52     4.551163
# 54     4.545657
# 179    3.820569
# 135    4.055102
# 83     4.354970
# 38     4.700000
# 114    4.218631
# 13     5.183453
# 26     4.895652
# 121    4.105983
# 124    4.088855
# 86     4.334716
# 76     4.447028
# 46     4.642539
# 69     4.468726

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# ###Collaborative based recommendation

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
print(x.shape)
padhe_likhe_users = x[x].index
# Out:
# (91905,)

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
print(y.shape)
famous_books = y[y].index
# Out:
# (151833,)

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [704 rows x 803 columns]

# %%
pt.shape
# Out:
# (704, 803)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_scores = cosine_similarity(pt)
similarity_scores.shape
# Out:
# (704, 704)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        # item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        # item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [["The Handmaid's Tale"],
#  ['Animal Farm'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)'],
#  ['Brave New World']]

# %%
recommend('Brave New World')
# Out:
# [['1984'],
#  ['Love in the Time of Cholera (Penguin Great Books of the 20th Century)'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)'],
#  ['The Gunslinger (The Dark Tower, Book 1)']]

# %%
recommend('Brave New World')
# Out:
# [['1984'],
#  ['Love in the Time of Cholera (Penguin Great Books of the 20th Century)'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)'],
#  ['The Gunslinger (The Dark Tower, Book 1)']]
