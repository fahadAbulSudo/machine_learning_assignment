# %%
import numpy as np
import os
import pandas as pd
import sympy
import matplotlib.pyplot as plt
import sys
from scipy.fftpack import rfft
from scipy.fft import rfft,rfftfreq
from scipy.fft import fft, ifft#
from scipy import signal

# %%
path = r'2nd_test'
filename = '2004.02.19.05.32.39'
dataset=pd.read_csv(os.path.join(path, filename), sep='\t',header=None)
dataset=pd.read_csv(r'2nd_test/2004.02.19.05.32.39', sep='\t',header=None)

# %%
dataset
# Out:
#            0      1      2      3
# 0     -0.796 -0.027  0.125  0.056
# 1     -0.017  0.132  0.042  0.298
# 2      0.574  0.193 -0.073  0.186
# 3     -0.774  0.234 -0.234 -0.068
# 4     -0.469  0.178 -0.120 -0.271
# ...      ...    ...    ...    ...
# 20475  0.034  0.222  0.020  0.046
# 20476 -0.344  0.293  0.020  0.066
# 20477 -0.322  0.359 -0.166  0.085
# 20478  0.251 -0.127 -0.339 -0.034
# 20479  0.383 -0.178 -0.188 -0.042
#
# [20480 rows x 4 columns]

# %%
for i in [0,1,2,3]:
    x = dataset.iloc[:,i].values
    # sampling rate
    sr = 20480
    # sampling interval
    X = rfft(x)#takes only unique values in dataset
    N = len(X)
    n = np.arange(N)#NumPy arange() is one of the array creation routines based on numerical ranges. It creates an instance of ndarray with evenly spaced values and returns the reference to it
    T = N/sr
    freq = n/T
    f = np.array(freq)
    np.set_printoptions(precision=8,suppress=True)
    len(f)
    plt.plot(f, np.abs(X), color = 'blue')
    plt.title("Frequency Domain")
    plt.xlabel('Frequency')
    plt.ylabel('Amplitude')
    plt.show()

# %%
path = r'2nd_test'
filename = '2004.02.12.10.32.39'
dataset=pd.read_csv(os.path.join(path, filename), sep='\t',header=None)
dataset=pd.read_csv(r'2nd_test/2004.02.12.10.32.39', sep='\t',header=None)

# %%
for i in [0,1,2,3]:
    x = dataset.iloc[:,i].values
    # sampling rate
    sr = 20480
    # sampling interval
    X = rfft(x)#takes only unique values in dataset
    N = len(X)
    n = np.arange(N)#NumPy arange() is one of the array creation routines based on numerical ranges. It creates an instance of ndarray with evenly spaced values and returns the reference to it
    T = N/sr
    freq = n/T
    f = np.array(freq)
    np.set_printoptions(precision=8,suppress=True)
    len(f)
    plt.plot(f, np.abs(X), color = 'blue')
    plt.title("Frequency Domain")
    plt.xlabel('Frequency')
    plt.ylabel('Amplitude')
    plt.show()

# %%
path = r'3rd_test'
filename = '2004.03.04.09.27.46'
dataset=pd.read_csv(os.path.join(path, filename), sep='\t',header=None)
dataset=pd.read_csv(r'3rd_test/2004.03.04.09.27.46', sep='\t',header=None)
for i in [0,1,2,3]:
    x = dataset.iloc[:,i].values
    # sampling rate
    sr = 20480
    # sampling interval
    X = rfft(x)#takes only unique values in dataset
    N = len(X)
    n = np.arange(N)#NumPy arange() is one of the array creation routines based on numerical ranges. It creates an instance of ndarray with evenly spaced values and returns the reference to it
    T = N/sr
    freq = n/T
    f = np.array(freq)
    np.set_printoptions(precision=8,suppress=True)
    len(f)
    plt.plot(f, np.abs(X), color = 'blue')
    plt.title("Frequency Domain")
    plt.xlabel('Frequency')
    plt.ylabel('Amplitude')
    plt.show()

# %%
path = r'3rd_test'
filename = '2004.03.11.23.12.46'
dataset=pd.read_csv(os.path.join(path, filename), sep='\t',header=None)
dataset=pd.read_csv(r'3rd_test/2004.03.11.23.12.46', sep='\t',header=None)
for i in [0,1,2,3]:
    x = dataset.iloc[:,i].values
    # sampling rate
    sr = 20480
    # sampling interval
    X = rfft(x)#takes only unique values in dataset
    N = len(X)
    n = np.arange(N)#NumPy arange() is one of the array creation routines based on numerical ranges. It creates an instance of ndarray with evenly spaced values and returns the reference to it
    T = N/sr
    freq = n/T
    f = np.array(freq)
    np.set_printoptions(precision=8,suppress=True)
    len(f)
    plt.plot(f, np.abs(X), color = 'blue')
    plt.title("Frequency Domain")
    plt.xlabel('Frequency')
    plt.ylabel('Amplitude')
    plt.show()

# %%
path = r'1st_test'
filename = '2003.10.22.12.09.13'
dataset=pd.read_csv(os.path.join(path, filename), sep='\t',header=None)
dataset=pd.read_csv(r'1st_test/2003.10.22.12.09.13', sep='\t',header=None)
