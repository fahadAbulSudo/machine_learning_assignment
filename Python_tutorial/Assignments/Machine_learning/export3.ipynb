# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import re
import pickle

# %%
employee_skill = pickle.load(open('../output/employee_skill.pkl', 'rb'))
similarity = pickle.load(open('../output/similarity.pkl', 'rb'))

# %%
employee_skill.columns
# Out:
# Index(['employee_id', 'employee_skills', 'first_name', 'last_name', 'category',
#        'department_name', 'designation_name', 'duhead_id', 'coehead_id', 'coe',
#        'name', 'work_location', 'project_type', 'allocation_percentage'],
#       dtype='object')

# %%
employee_skill.head()
# Out:
#   employee_id                                    employee_skills  first_name  \
# 0    AFT00047  Manual Testing Functional Testing   Testing,Pe...    Priyanka
# 1    AFT00084  Build&Deploy DevOps Jenkins Coding & Developme...       Samir
# 2    AFT00099  Automation Testing Specialized Testing Python/...  Prathamesh
# 3    AFT00252  Full Stack Web Technologies Intermediate Codin...       Sunil
# 4    AFT00257  Manual Testing Functional Testing   Testing,Di...         NaN
#
#   last_name  category department_name  \
# 0     Gurav  EMPLOYEE     Engineering
# 1  Joglekar  EMPLOYEE     Engineering
# 2    Sarang  EMPLOYEE     Engineering
# 3      Jain    INTERN     Engineering
# 4       NaN   no_info             NaN
#
#                                designation_name  \
# 0  Principal Software Development Engineer-Test
# 1         Associate Software Solution Architect
# 2              Software Test Solution Architect
# 3       Principal Software Development Engineer
# 4                                       no_info
#
#                         duhead_id            coehead_id  \
# 0            [AFT00304, AFT00640]            [AFT00640]
# 1            [AFT00599, AFT00628]  [AFT00599, AFT00628]
# 2  [AFT00304, AFT00640, AFT00129]            [AFT00640]
# 3            [AFT00628, AFT00640]  [AFT00599, AFT00640]
# 4                         no_info               no_info
#
#                                              coe  \
# 0                      [RELIABILITY_ENGINEERING]
# 1                           [DESIGN_DEVELOPMENT]
# 2  [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]
# 3                           [DESIGN_DEVELOPMENT]
# 4                                        no_info
#
#                                                 name       work_location  \
# 0                  [Stellus, Unitrends, Trial Scope]          [OFFSHORE]
# 1             [Marchex (Sustenance), Marchex – OCPS]  [ONSITE, OFFSHORE]
# 2  [Automation training, QAccelerator, Bench, Man...          [OFFSHORE]
# 3                [Convoy, Convoy- New, Convoy – EDI]          [OFFSHORE]
# 4                                            no_info             no_info
#
#         project_type  allocation_percentage
# 0         [CUSTOMER]                  400.0
# 1         [CUSTOMER]                  300.0
# 2  [ASSET, CUSTOMER]                 1000.0
# 3         [CUSTOMER]                  300.0
# 4            no_info                    0.0

# %%
def recommend(employee_id):
  sim = []
  employee_lst = []
  index = employee_skill[employee_skill['employee_id'] == employee_id].index[0]
  distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
  for i in distances[1:10]:
    employee_lst.append(employee_skill.employee_id[i[0]])
    sim.append(i[1])
  sim = [x * 100 for x in sim]
  sim = [ '%.2f' % elem for elem in sim ]
  lst = list(zip(employee_lst, sim))
  return lst

# %%
employee_skill.columns
# Out:
# Index(['employee_id', 'employee_skills', 'first_name', 'last_name', 'category',
#        'department_name', 'designation_name', 'duhead_id', 'coehead_id', 'coe',
#        'name', 'work_location', 'project_type', 'allocation_percentage'],
#       dtype='object')

# %%
employee_skill.head(3)
# Out:
#   employee_id                                    employee_skills  first_name  \
# 0    AFT00047  Manual Testing Functional Testing   Testing,Pe...    Priyanka
# 1    AFT00084  Build&Deploy DevOps Jenkins Coding & Developme...       Samir
# 2    AFT00099  Automation Testing Specialized Testing Python/...  Prathamesh
#
#   last_name  category department_name  \
# 0     Gurav  EMPLOYEE     Engineering
# 1  Joglekar  EMPLOYEE     Engineering
# 2    Sarang  EMPLOYEE     Engineering
#
#                                designation_name  \
# 0  Principal Software Development Engineer-Test
# 1         Associate Software Solution Architect
# 2              Software Test Solution Architect
#
#                         duhead_id            coehead_id  \
# 0            [AFT00304, AFT00640]            [AFT00640]
# 1            [AFT00599, AFT00628]  [AFT00599, AFT00628]
# 2  [AFT00304, AFT00640, AFT00129]            [AFT00640]
#
#                                              coe  \
# 0                      [RELIABILITY_ENGINEERING]
# 1                           [DESIGN_DEVELOPMENT]
# 2  [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]
#
#                                                 name       work_location  \
# 0                  [Stellus, Unitrends, Trial Scope]          [OFFSHORE]
# 1             [Marchex (Sustenance), Marchex – OCPS]  [ONSITE, OFFSHORE]
# 2  [Automation training, QAccelerator, Bench, Man...          [OFFSHORE]
#
#         project_type  allocation_percentage
# 0         [CUSTOMER]                  400.0
# 1         [CUSTOMER]                  300.0
# 2  [ASSET, CUSTOMER]                 1000.0

# %%
employee = "AFT00511"

# %%
def mapping_desig(val):
    mask = employee_skill['employee_id'].values == employee
    df_new = employee_skill.loc[mask]
    val_desig = df_new.designation_name.values[0]
    if val == val_desig:
        return 1
    else:
        return 0

def mapping_depar(val):
    mask = employee_skill['employee_id'].values == employee
    df_new = employee_skill.loc[mask]
    val_depar = df_new.department_name.values[0]
    if val == val_depar:
        return 1
    else:
        return 0

# %%
employee_lst = recommend(employee)
employee_lst
# Out:
# [('AFT00671', '94.22'),
#  ('AFTC0224', '93.86'),
#  ('AFT00662', '90.75'),
#  ('AFT00408', '89.37'),
#  ('AFT00661', '89.34'),
#  ('AFT00513', '87.29'),
#  ('AFT00688', '87.19'),
#  ('AFT00084', '86.91'),
#  ('AFT00505', '86.17')]

# %%
employee_skill.head()
# Out:
#   employee_id                                    employee_skills  first_name  \
# 0    AFT00047  Manual Testing Functional Testing   Testing,Pe...    Priyanka
# 1    AFT00084  Build&Deploy DevOps Jenkins Coding & Developme...       Samir
# 2    AFT00099  Automation Testing Specialized Testing Python/...  Prathamesh
# 3    AFT00252  Full Stack Web Technologies Intermediate Codin...       Sunil
# 4    AFT00257  Manual Testing Functional Testing   Testing,Di...         NaN
#
#   last_name  category department_name  \
# 0     Gurav  EMPLOYEE     Engineering
# 1  Joglekar  EMPLOYEE     Engineering
# 2    Sarang  EMPLOYEE     Engineering
# 3      Jain    INTERN     Engineering
# 4       NaN   no_info             NaN
#
#                                designation_name  \
# 0  Principal Software Development Engineer-Test
# 1         Associate Software Solution Architect
# 2              Software Test Solution Architect
# 3       Principal Software Development Engineer
# 4                                       no_info
#
#                         duhead_id            coehead_id  \
# 0            [AFT00304, AFT00640]            [AFT00640]
# 1            [AFT00599, AFT00628]  [AFT00599, AFT00628]
# 2  [AFT00304, AFT00640, AFT00129]            [AFT00640]
# 3            [AFT00628, AFT00640]  [AFT00599, AFT00640]
# 4                         no_info               no_info
#
#                                              coe  \
# 0                      [RELIABILITY_ENGINEERING]
# 1                           [DESIGN_DEVELOPMENT]
# 2  [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]
# 3                           [DESIGN_DEVELOPMENT]
# 4                                        no_info
#
#                                                 name       work_location  \
# 0                  [Stellus, Unitrends, Trial Scope]          [OFFSHORE]
# 1             [Marchex (Sustenance), Marchex – OCPS]  [ONSITE, OFFSHORE]
# 2  [Automation training, QAccelerator, Bench, Man...          [OFFSHORE]
# 3                [Convoy, Convoy- New, Convoy – EDI]          [OFFSHORE]
# 4                                            no_info             no_info
#
#         project_type  allocation_percentage
# 0         [CUSTOMER]                  400.0
# 1         [CUSTOMER]                  300.0
# 2  [ASSET, CUSTOMER]                 1000.0
# 3         [CUSTOMER]                  300.0
# 4            no_info                    0.0

# %%
def sorted_dataframe(employee_lst, employee):
    employee_lst = [[i for i, j in employee_lst],
       [j for i, j in employee_lst]]
    lst = employee_lst[0]
    sim = employee_lst[1]
    sim.append(0)
    p = len(sim)-1
    while(p>0):
        sim[p] = sim[p-1]
        p = p - 1
    sim[0] = 0
    print(sim)

    mask = employee_skill['employee_id'].values == employee
    df_new = employee_skill.loc[mask]
    for employee1 in lst:
        mask = employee_skill['employee_id'].values == employee1
 
# using loc() method
        df_new1 = employee_skill.loc[mask]
        df_new = df_new.append(df_new1, ignore_index = True) 
    df_new2 = df_new.loc[1:]
    df_new['similarity'] = sim
    b = df_new2.iloc[:,5:6].values
    b = b.reshape(-1)
    b=b.tolist()
    encoded_de = []
    for value in b:
        encoded_de.append(mapping_depar(value))
    df_new2['department_name'] = encoded_de
    b=df_new2.iloc[:,4:5].values
    b = b.reshape(-1)
    b.shape
    b=b.tolist()
    encoded_category = []
    for category in b:
        if category == "EMPLOYEE":
            encoded_category.append(2)
        elif category == "Intern" or category == "CONTRACT":
            encoded_category.append(1)
        else:
            encoded_category.append(0)

    df_new2['category'] = encoded_category
    
    mask = employee_skill['employee_id'].values == employee
    df_new6 = employee_skill.loc[mask]
    #print(df_new1)
    coe = df_new6.coe.values[0]
    del df_new6
    b=df_new2.iloc[:,9:10].values
    b = b.reshape(-1)
    b.shape
    b=b.tolist()
    
    encoded_coe = []
    if len(coe) == 2:
        for val in b:
            if len(val) == 2:
                encoded_coe.append(2)
            elif val[0] == 'DESIGN_DEVELOPMENT' or val[0] == 'DESIGN_DEVELOPMENT':
                encoded_coe.append(1)
            else:
                encoded_coe.append(0)
    elif coe[0] == "DESIGN_DEVELOPMENT":
        for val in b:
            if len(val) == 2 or val[0] == "DESIGN_DEVELOPMENT":
                encoded_coe.append(2)
            else:
                encoded_coe.append(0)
    elif coe[0] == "RELIABILITY_ENGINEERING":
        for val in b:
            if len(val) == 2 or val[0] == "RELIABILITY_ENGINEERING":
                encoded_coe.append(2)
            else:
                encoded_coe.append(0)
    else:
        for val in b:
            if len(val) == 2:
                encoded_coe.append(2)
            elif len(val) == 1:
                encoded_coe.append(1)
            else:
                encoded_coe.append(0)

    df_new2['coe'] = encoded_coe

    b=df_new2.iloc[:,10:11].values
    b = b.reshape(-1)
    b.shape
    b=b.tolist() 

    name_recommend = []
    for val in b:
        if "Bench" in val:
            name_recommend.append(1)
        else:
            name_recommend.append(0)

    df_new2['name'] = name_recommend
    b=df_new2.iloc[:,6:7].values
    b = b.reshape(-1)
    b.shape
    b=b.tolist()

    encoded_hierarchy = []
    for value in b:
        encoded_hierarchy.append(mapping_desig(value))

    df_new2['designation_name'] = encoded_hierarchy
    
    mask = employee_skill['employee_id'].values == employee
    df_new4 = employee_skill.loc[mask]
    duheadid = df_new4.duhead_id.values[0]
    del df_new4

    b=df_new2.iloc[:,7:8].values
    b = b.reshape(-1)
    b.shape
    b=b.tolist()

    du_recommend = []
    for val in b:
        lst5 = []
        for heads in val:
            if heads in duheadid:
                lst5.append(1)
            else:
                lst5.append(0)

        if 1 in lst5:
            du_recommend.append(1)
        else:
            du_recommend.append(0)

    df_new2['duhead_id'] = du_recommend

    mask = employee_skill['employee_id'].values == employee
    df_new4 = employee_skill.loc[mask]
    coeheadid = df_new4.coehead_id.values[0]
    del df_new4

    b=df_new2.iloc[:,8:9].values
    b = b.reshape(-1)
    b.shape
    b=b.tolist()

    co_recommend = []
    for val in b:
        lst5 = []
        for heads in val:
            if heads in coeheadid:
                lst5.append(1)
            else:
                lst5.append(0)

        if 1 in lst5:
            co_recommend.append(1)
        else:
            co_recommend.append(0)

    df_new2['coehead_id'] = co_recommend
    mask = employee_skill['employee_id'].values == employee
    df_new6 = employee_skill.loc[mask]
    worklocation = df_new6.work_location.values[0]
    del df_new6

    b=df_new2.iloc[:,11:12].values
    b = b.reshape(-1)
    b=b.tolist()

    work_en = []
    for val in b:
        lst5 = []
        for locations in val:
            if locations in worklocation:
                lst5.append(1)
            else:
                lst5.append(0)

        if 1 in lst5:
            work_en.append(1)
        else:
            work_en.append(0)

    df_new2['work_location'] = work_en
    
    b=df_new2.iloc[:,12:13].values
    b = b.reshape(-1)
    b=b.tolist()

    encoded_pt = []
    for val in b:
        if len(val) == 2 or val[0] == "CUSTOMER":
            encoded_pt.append(0)
        elif val[0] == 'ASSET':
            encoded_pt.append(1)
        else:
            encoded_pt.append(1)
    df_new2['project_type'] = encoded_pt

    df_new3 = df_new2[['category', 'department_name',
        'designation_name', 'duhead_id', 'coehead_id', 'coe',
       'name', 'work_location', 'project_type']].copy()

    listOfDFRows = df_new3.to_numpy().tolist()

    sum = []
    for val in listOfDFRows:
        count = 0
        for i in val:
            count = count + i
        sum.append(count)

    df_re = df_new.loc[1:]
    df_re['Imporance_value'] = sum
    res_df = df_re.sort_values(by = 'Imporance_value', ascending = False)
    res_df.drop(columns=['duhead_id', 'coehead_id', 'name',
        'allocation_percentage','Imporance_value'], axis=1, inplace=True)
    res_df.loc[res_df["coe"] == 'no_info', "coe"] = "--"
    res_df.loc[res_df["work_location"] == 'no_info', "work_location"] = "--"
    res_df.loc[res_df["project_type"] == 'no_info', "project_type"] = "--"
    res_df.loc[res_df["designation_name"] == "no_info", "designation_name"] = "--"
    res_df.loc[res_df["category"] == "no_info", "category"] = "--"
    res_df['department_name'] = res_df['department_name'].fillna("--")
    res_df['first_name'] = res_df['first_name'].fillna("--")
    res_df['last_name'] = res_df['last_name'].fillna("--")
    res_df = res_df[['employee_id', 'first_name', 'last_name', 'category',
       'department_name', 'designation_name', 'coe',
        'work_location', 'project_type', 'similarity', 'employee_skills']]
    res_df.set_index("employee_id", inplace = True)
    
    return res_df

# %%
recommendations = sorted_dataframe(employee_lst, employee)
# Out:
# [0, '94.22', '93.86', '90.75', '89.37', '89.34', '87.29', '87.19', '86.91', '86.17']

# %%
recommendations
# Out:
#             first_name last_name  category department_name  \
# employee_id
# AFT00671       Utkarsh     Singh  EMPLOYEE     Engineering
# AFT00662        Manish     Walde  EMPLOYEE     Engineering
# AFT00661          Ravi   Bhoskar  EMPLOYEE     Engineering
# AFT00408         Sonal    Yewale  EMPLOYEE     Engineering
# AFT00688     Parikshit     Nagda  CONTRACT     Engineering
# AFT00505       Shubham         m  EMPLOYEE     Engineering
# AFT00084         Samir  Joglekar  EMPLOYEE     Engineering
# AFT00513        Nikhil   Malviya    INTERN     Engineering
# AFTC0224            --        --        --              --
#
#                                     designation_name  \
# employee_id
# AFT00671               Software Development Engineer
# AFT00662          Lead Software Development Engineer
# AFT00661        Senior Software Development Engineer
# AFT00408     Principal Software Development Engineer
# AFT00688          Lead Software Development Engineer
# AFT00505               Software Development Engineer
# AFT00084       Associate Software Solution Architect
# AFT00513                 Associate Software Engineer
# AFTC0224                                          --
#
#                                                        coe  \
# employee_id
# AFT00671     [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]
# AFT00662     [RELIABILITY_ENGINEERING, DESIGN_DEVELOPMENT]
# AFT00661     [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]
# AFT00408     [RELIABILITY_ENGINEERING, DESIGN_DEVELOPMENT]
# AFT00688     [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]
# AFT00505                              [DESIGN_DEVELOPMENT]
# AFT00084                              [DESIGN_DEVELOPMENT]
# AFT00513                              [DESIGN_DEVELOPMENT]
# AFTC0224                                                --
#
#                            work_location       project_type similarity  \
# employee_id
# AFT00671                      [OFFSHORE]  [CUSTOMER, ASSET]      94.22
# AFT00662     [OFFSHORE, ONSITE_OFFSHORE]  [ASSET, CUSTOMER]      90.75
# AFT00661                      [OFFSHORE]  [CUSTOMER, ASSET]      89.34
# AFT00408                      [OFFSHORE]  [ASSET, CUSTOMER]      89.37
# AFT00688                      [OFFSHORE]  [CUSTOMER, ASSET]      87.19
# AFT00505                      [OFFSHORE]         [CUSTOMER]      86.17
# AFT00084              [ONSITE, OFFSHORE]         [CUSTOMER]      86.91
# AFT00513                      [OFFSHORE]         [CUSTOMER]      87.29
# AFTC0224                              --                 --      93.86
#
#                                                employee_skills
# employee_id
# AFT00671     Container DevOps Docker Coding & Development,C...
# AFT00662     ALM Microsoft Visual Studio 2015 Coding & Deve...
# AFT00661     Framework Microsoft .Net 2.0/3.0/4.0/4.5 Codin...
# AFT00408     Framework Microsoft Jquery Coding & Developmen...
# AFT00688     Script Language Microsoft Javascript Coding & ...
# AFT00505     Change Management Microsoft TFS, Git Coding & ...
# AFT00084     Build&Deploy DevOps Jenkins Coding & Developme...
# AFT00513     Container DevOps Docker Coding & Development,O...
# AFTC0224     Build&Deploy DevOps Jenkins Coding & Developme...

# %%
lst = recommend("AFT00252")
lst
# Out:
# ['AFT00456',
#  'AFT00448',
#  'AFT00602',
#  'AFT00505',
#  'AFT00583',
#  'AFT00537',
#  'AFT00594',
#  'AFT00408',
#  'AFTI0019']

# %%
recommendations = sorted_dataframe(lst, "AFT00252")

# %%
recommendations
# Out:
#                                                employee_skills first_name  \
# employee_id
# AFT00505     Change Management Microsoft TFS, Git Coding & ...    Shubham
# AFT00456     Web Technology Java Typescript Coding & Develo...      Rahul
# AFT00594     Web Technology General JSON Coding & Developme...    Abhijit
# AFT00408     Framework Microsoft Jquery Coding & Developmen...      Sonal
# AFTI0019     Web Technology Java React JS Coding & Developm...  Deepanshu
# AFT00602     Full Stack Web Technologies Intermediate Codin...    Deepika
# AFT00537     Web Technology General JSON Coding & Developme...     Dhiraj
# AFT00448     Full Stack Web Technologies Advanced Coding & ...         --
# AFT00583     Data Architecture Data Management Data Modelin...         --
#
#             last_name  category department_name  \
# employee_id
# AFT00505            m  EMPLOYEE     Engineering
# AFT00456       Sharma  EMPLOYEE     Engineering
# AFT00594     Kulkarni  EMPLOYEE     Engineering
# AFT00408       Yewale  EMPLOYEE     Engineering
# AFTI0019       Bansal    INTERN     Engineering
# AFT00602      Ahirrao  EMPLOYEE     Engineering
# AFT00537      Ghavate  EMPLOYEE     Engineering
# AFT00448           --        --              --
# AFT00583           --        --              --
#
#                                     designation_name  \
# employee_id
# AFT00505               Software Development Engineer
# AFT00456        Senior Software Development Engineer
# AFT00594          Lead Software Development Engineer
# AFT00408     Principal Software Development Engineer
# AFTI0019                                      Intern
# AFT00602     Principal Software Development Engineer
# AFT00537          Lead Software Development Engineer
# AFT00448                                          --
# AFT00583                                          --
#
#                                                        coe work_location  \
# employee_id
# AFT00505                              [DESIGN_DEVELOPMENT]    [OFFSHORE]
# AFT00456                              [DESIGN_DEVELOPMENT]    [OFFSHORE]
# AFT00594     [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]    [OFFSHORE]
# AFT00408     [RELIABILITY_ENGINEERING, DESIGN_DEVELOPMENT]    [OFFSHORE]
# AFTI0019     [DESIGN_DEVELOPMENT, RELIABILITY_ENGINEERING]    [OFFSHORE]
# AFT00602                         [RELIABILITY_ENGINEERING]    [OFFSHORE]
# AFT00537                         [RELIABILITY_ENGINEERING]    [OFFSHORE]
# AFT00448                                                --            --
# AFT00583                                                --            --
#
#                   project_type
# employee_id
# AFT00505            [CUSTOMER]
# AFT00456            [CUSTOMER]
# AFT00594     [CUSTOMER, ASSET]
# AFT00408     [ASSET, CUSTOMER]
# AFTI0019               [ASSET]
# AFT00602     [ASSET, CUSTOMER]
# AFT00537            [CUSTOMER]
# AFT00448                    --
# AFT00583                    --

# %%
lst = recommend("AFT00641")
recommendations = sorted_dataframe(lst, "AFT00641")
recommendations
# Out:
#    employee_id category_x               designation_name first_name last_name
# 3     AFT00641   EMPLOYEE           Lead DevOps Engineer      Rohan    Shinde
# 4     AFT00526   EMPLOYEE           Lead DevOps Engineer     Yogesh   Rathore
# 5     AFT00623   EMPLOYEE    Associate Software Engineer    Krishna     Kekan
# 6     AFT00614   EMPLOYEE                Devops Engineer    Avadhut    Talbar
# 10    AFT00671   EMPLOYEE  Software Development Engineer    Utkarsh     Singh
# 2     AFT00613   EMPLOYEE    Associate Software Engineer     Girish      Mane
# 8     AFT00513     INTERN    Associate Software Engineer     Nikhil   Malviya
# 1     AFT00554    no_info                        no_info        NaN       NaN
# 7     AFT00565    no_info                        no_info        NaN       NaN
# 9     AFTC0224    no_info                        no_info        NaN       NaN
